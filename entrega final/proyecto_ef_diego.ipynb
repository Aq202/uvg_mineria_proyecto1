# %%
import pandas as pd

# %% [markdown]
# ### Cargar y modelar datos generales

# %%
ods_data = pd.read_csv("ODS_indicators.csv")

# %%
ods_data.drop(["Country Name", "Indicator Code"], axis=1, inplace=True)
ods_data.drop([str(year) for year in range(1990, 2005)], axis=1, inplace=True)

# %%
melted_df = ods_data.melt(id_vars=['Country Code', 'Indicator Name'], var_name='Year', value_name='Value')


ods_data = melted_df.pivot_table(index=['Country Code', 'Year'], columns='Indicator Name', values='Value')


ods_data.reset_index(inplace=True)

ods_data
# Out:
# Indicator Name Country Code  Year  \
# 0                       ABW  2005
# 1                       ABW  2006
# 2                       ABW  2007
# 3                       ABW  2008
# 4                       ABW  2009
# ...                     ...   ...
# 4168                    ZWE  2016
# 4169                    ZWE  2017
# 4170                    ZWE  2018
# 4171                    ZWE  2019
# 4172                    ZWE  2020
#
# Indicator Name  Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 4168                                                         29.8
# 4169                                                         29.8
# 4170                                                         29.9
# 4171                                                         30.1
# 4172                                                         30.4
#
# Indicator Name  Access to electricity (% of population)  \
# 0                                            100.000000
# 1                                            100.000000
# 2                                            100.000000
# 3                                            100.000000
# 4                                            100.000000
# ...                                                 ...
# 4168                                          42.561729
# 4169                                          44.178635
# 4170                                          45.572647
# 4171                                          46.781475
# 4172                                          52.747669
#
# Indicator Name  Adolescent fertility rate (births per 1000 women ages 15-19)  \
# 0                                                         36.7648
# 1                                                         35.3134
# 2                                                         33.8620
# 3                                                         32.7920
# 4                                                         31.7220
# ...                                                           ...
# 4168                                                      90.6766
# 4169                                                      86.1350
# 4170                                                      83.2486
# 4171                                                      80.3622
# 4172                                                      77.4758
#
# Indicator Name  Adolescents out of school (% of lower secondary school age)  \
# 0                                                        6.071430
# 1                                                             NaN
# 2                                                        3.847370
# 3                                                        3.824090
# 4                                                        7.427830
# ...                                                           ...
# 4168                                                     2.261470
# 4169                                                     2.356790
# 4170                                                     6.226070
# 4171                                                     7.544310
# 4172                                                    21.875412
#
# Indicator Name  Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 4168                                                    66.879997
# 4169                                                    66.480003
# 4170                                                    66.019997
# 4171                                                    66.190002
# 4172                                                          NaN
#
# Indicator Name  Employment in industry (% of total employment) (modeled ILO estimate)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 4168                                                         7.05
# 4169                                                         6.90
# 4170                                                         6.75
# 4171                                                         6.57
# 4172                                                          NaN
#
# Indicator Name  Employment in services (% of total employment) (modeled ILO estimate)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 4168                                                    26.070000
# 4169                                                    26.629999
# 4170                                                    27.230000
# 4171                                                    27.240000
# 4172                                                          NaN
#
# Indicator Name  GDP per capita (current US$)  \
# 0                               23591.159840
# 1                               24495.015390
# 2                               26452.231950
# 3                               28048.151770
# 4                               25170.832360
# ...                                      ...
# 4168                             1464.588957
# 4169                             1235.189032
# 4170                             1254.642265
# 4171                             1316.740657
# 4172                             1214.509820
#
# Indicator Name  Households and NPISHs Final consumption expenditure (annual % growth)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 4168                                                   -10.501114
# 4169                                                     1.396143
# 4170                                                   -22.393220
# 4171                                                          NaN
# 4172                                                          NaN
#
# Indicator Name  Individuals using the Internet (% of population)  \
# 0                                                      25.400000
# 1                                                      28.000000
# 2                                                      30.900000
# 3                                                      52.000000
# 4                                                      58.000000
# ...                                                          ...
# 4168                                                   23.119989
# 4169                                                   24.400000
# 4170                                                   25.000000
# 4171                                                   25.100000
# 4172                                                   29.300000
#
# Indicator Name  People using at least basic drinking water services (% of population)  \
# 0                                                       95.897230
# 1                                                       96.178915
# 2                                                       96.460600
# 3                                                       96.742284
# 4                                                       97.023969
# ...                                                           ...
# 4168                                                    64.468964
# 4169                                                    63.996625
# 4170                                                    63.538773
# 4171                                                    63.094957
# 4172                                                    62.666458
#
# Indicator Name  People using at least basic sanitation services (% of population)  \
# 0                                                       97.996573
# 1                                                       97.931846
# 2                                                       97.867118
# 3                                                       97.802391
# 4                                                       97.737663
# ...                                                           ...
# 4168                                                    37.529193
# 4169                                                    36.941673
# 4170                                                    36.357160
# 4171                                                    35.774337
# 4172                                                    35.192363
#
# Indicator Name  People using safely managed drinking water services (% of population)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 4168                                                    30.183683
# 4169                                                    29.997683
# 4170                                                    29.827913
# 4171                                                    29.673569
# 4172                                                    29.535890
#
# Indicator Name  Primary completion rate total (% of relevant age group)  \
# 0                                                       88.197968
# 1                                                       93.186119
# 2                                                       95.588242
# 3                                                       95.133034
# 4                                                       96.242577
# ...                                                           ...
# 4168                                                    99.265839
# 4169                                                    95.476372
# 4170                                                    92.195152
# 4171                                                    88.508812
# 4172                                                    90.017349
#
# Indicator Name  Unemployment total (% of total labor force) (modeled ILO estimate)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 4168                                                        4.788
# 4169                                                        4.785
# 4170                                                        4.796
# 4171                                                        4.833
# 4172                                                        5.351
#
# Indicator Name  Urban population (% of total population)
# 0                                                 44.875
# 1                                                 44.511
# 2                                                 44.147
# 3                                                 43.783
# 4                                                 43.421
# ...                                                  ...
# 4168                                              32.296
# 4169                                              32.237
# 4170                                              32.209
# 4171                                              32.210
# 4172                                              32.242
#
# [4173 rows x 18 columns]

# %% [markdown]
# ### Cargar y moldear datos de indicadores

# %%
indicators_data = pd.read_csv("HDR23-24_Composite_indices_complete_time_series.csv",  encoding='latin1')

# %%
# Eliminar columnas
indicators_data = indicators_data.drop(["hdicode","region"], axis=1)
indicators_data = indicators_data.rename(columns={"iso3":"Country Code"})

# %%
# Usar pd.melt para aplanar el DataFrame
df_melted = pd.melt(indicators_data, id_vars=['Country Code', 'country'], var_name='variable_year', value_name='value')

# Separar 'variable' y 'year' usando rsplit
df_melted[['variable', 'Year']] = df_melted['variable_year'].str.rsplit('_', n=1, expand=True)

# Pivotar para tener una columna por cada variable
indicators_data = df_melted.pivot_table(index=['Country Code', 'country', 'Year'], columns='variable', values='value').reset_index()
indicators_data
# Out:
# variable Country Code      country  Year         abr  co2_prod  coef_ineq  \
# 0                 AFG  Afghanistan  1990  142.960000  0.189279        NaN
# 1                 AFG  Afghanistan  1991  147.525000  0.178155        NaN
# 2                 AFG  Afghanistan  1992  147.521000  0.122920        NaN
# 3                 AFG  Afghanistan  1993  147.896000  0.106179        NaN
# 4                 AFG  Afghanistan  1994  155.669000  0.094063        NaN
# ...               ...          ...   ...         ...       ...        ...
# 6793        ZZK.WORLD        World  2018   44.140624  4.601230  22.361032
# 6794        ZZK.WORLD        World  2019   43.433319  4.589431  22.042156
# 6795        ZZK.WORLD        World  2020   42.805263  4.336829  21.945371
# 6796        ZZK.WORLD        World  2021   42.529066  4.520335  21.832743
# 6797        ZZK.WORLD        World  2022   41.924402  4.497895  21.732077
#
# variable  diff_hdi_phdi        eys      eys_f      eys_m  ...       mys  \
# 0              1.056338   2.936460   2.117230   4.532768  ...  0.871962
# 1              1.027397   3.228456   2.246242   4.768261  ...  0.915267
# 2              1.003344   3.520452   2.383115   5.015989  ...  0.958573
# 3              0.977199   3.812448   2.528328   5.276587  ...  1.001878
# 4              0.666667   4.104445   2.682390   5.550723  ...  1.045184
# ...                 ...        ...        ...        ...  ...       ...
# 6793           7.482993  12.651182  12.694327  12.615530  ...  8.483187
# 6794           7.171854  12.726141  12.803410  12.657070  ...  8.574383
# 6795           7.201087  12.860674  12.937502  12.795625  ...  8.686374
# 6796           7.346939  12.911840  12.998299  12.833189  ...  8.682265
# 6797           7.307172  12.989766  13.082218  12.907841  ...  8.661598
#
# variable     mys_f     mys_m   phdi    pop_total       pr_f       pr_m  \
# 0         0.201659  1.493952  0.281    10.694796        NaN        NaN
# 1         0.218944  1.578809  0.289    10.745167        NaN        NaN
# 2         0.236229  1.663665  0.296    12.057433        NaN        NaN
# 3         0.253514  1.748522  0.304    14.003760        NaN        NaN
# 4         0.270800  1.833378  0.298    15.455554        NaN        NaN
# ...            ...       ...    ...          ...        ...        ...
# 6793      7.932751  9.047396  0.680  7649.567694  24.098697  75.901303
# 6794      8.059405  9.121410  0.686  7730.660623  24.670774  75.329226
# 6795      8.246301  9.155630  0.683  7806.602793  25.370844  74.629156
# 6796      8.250592  9.140639  0.681  7874.877719  25.913010  74.086990
# 6797      8.231362  9.118253  0.685  7940.608797  26.184549  73.815451
#
# variable  rankdiff_hdi_phdi       se_f       se_m
# 0                       NaN   1.107733   7.899011
# 1                       NaN   1.221396   8.137953
# 2                       NaN   1.335059   8.376896
# 3                       NaN   1.448722   8.615838
# 4                       NaN   1.562385   8.854780
# ...                     ...        ...        ...
# 6793                    NaN  62.161959  69.593772
# 6794                    NaN  62.953836  70.542738
# 6795                    NaN  64.385236  71.331807
# 6796                    NaN  64.325131  71.182639
# 6797                    NaN  64.118558  70.967411
#
# [6798 rows x 43 columns]

# %% [markdown]
# ### Juntar conjunto de datos

# %%
data = pd.merge(ods_data, indicators_data, on=['Country Code', 'Year'])
data
# Out:
#      Country Code  Year  \
# 0             AFG  2005
# 1             AFG  2006
# 2             AFG  2007
# 3             AFG  2008
# 4             AFG  2009
# ...           ...   ...
# 3115          ZWE  2016
# 3116          ZWE  2017
# 3117          ZWE  2018
# 3118          ZWE  2019
# 3119          ZWE  2020
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                 12.20
# 1                                                 13.85
# 2                                                 15.30
# 3                                                 16.70
# 4                                                 18.40
# ...                                                 ...
# 3115                                              29.80
# 3116                                              29.80
# 3117                                              29.90
# 3118                                              30.10
# 3119                                              30.40
#
#       Access to electricity (% of population)  \
# 0                                   25.390894
# 1                                   30.718691
# 2                                   36.051010
# 3                                   42.400002
# 4                                   46.740051
# ...                                       ...
# 3115                                42.561729
# 3116                                44.178635
# 3117                                45.572647
# 3118                                46.781475
# 3119                                52.747669
#
#       Adolescent fertility rate (births per 1000 women ages 15-19)  \
# 0                                              138.4284
# 1                                              135.7602
# 2                                              133.0920
# 3                                              126.6330
# 4                                              120.1740
# ...                                                 ...
# 3115                                            90.6766
# 3116                                            86.1350
# 3117                                            83.2486
# 3118                                            80.3622
# 3119                                            77.4758
#
#       Adolescents out of school (% of lower secondary school age)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3115                                           2.261470
# 3116                                           2.356790
# 3117                                           6.226070
# 3118                                           7.544310
# 3119                                          21.875412
#
#       Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                             62.150002
# 1                                             61.279999
# 2                                             60.139999
# 3                                             59.290001
# 4                                             56.889999
# ...                                                 ...
# 3115                                          66.879997
# 3116                                          66.480003
# 3117                                          66.019997
# 3118                                          66.190002
# 3119                                                NaN
#
#       Employment in industry (% of total employment) (modeled ILO estimate)  \
# 0                                                 11.33
# 1                                                 11.79
# 2                                                 12.20
# 3                                                 12.48
# 4                                                 13.63
# ...                                                 ...
# 3115                                               7.05
# 3116                                               6.90
# 3117                                               6.75
# 3118                                               6.57
# 3119                                                NaN
#
#       Employment in services (% of total employment) (modeled ILO estimate)  \
# 0                                             26.530001
# 1                                             26.930000
# 2                                             27.660000
# 3                                             28.230000
# 4                                             29.480000
# ...                                                 ...
# 3115                                          26.070000
# 3116                                          26.629999
# 3117                                          27.230000
# 3118                                          27.240000
# 3119                                                NaN
#
#       GDP per capita (current US$)  ...       mys     mys_f     mys_m   phdi  \
# 0                       242.031313  ...  1.521544  0.480141  2.509840  0.399
# 1                       263.733602  ...  1.595281  0.495506  2.620990  0.407
# 2                       359.693158  ...  1.669017  0.510870  2.732140  0.423
# 3                       364.663542  ...  1.742754  0.526235  2.843290  0.428
# 4                       437.268740  ...  1.816490  0.541599  2.954440  0.438
# ...                            ...  ...       ...       ...       ...    ...
# 3115                   1464.588957  ...  8.425370  7.881975  9.090810  0.539
# 3116                   1235.189032  ...  8.461690  8.061880  8.916270  0.544
# 3117                   1254.642265  ...  8.574575  8.065950  9.189455  0.556
# 3118                   1316.740657  ...  8.687460  8.070020  9.462640  0.553
# 3119                   1214.509820  ...  8.807763  8.190793  9.590724  0.545
#
#       pop_total       pr_f       pr_m  rankdiff_hdi_phdi       se_f       se_m
# 0     24.411191  25.925926  74.074074                NaN   3.024593  12.915637
# 1     25.442944  25.925926  74.074074                NaN   2.985100  13.786732
# 2     25.903301  25.872093  74.127907                NaN   2.945607  14.657827
# 3     26.427199  25.872093  74.127907                NaN   2.906114  15.528922
# 4     27.385307  25.925926  74.074074                NaN   2.866621  16.400018
# ...         ...        ...        ...                ...        ...        ...
# 3115  14.452704  35.142857  64.857143                NaN  53.450329  66.209465
# 3116  14.751101  36.151604  63.848396                NaN  59.792019  70.783081
# 3117  15.052184  34.285714  65.714286                NaN  60.982430  71.707101
# 3118  15.354608  34.571429  65.428571                NaN  62.196541  72.643183
# 3119  15.669666  34.571429  65.428571                NaN  63.434824  73.591485
#
# [3120 rows x 59 columns]

# %%
data.columns
# Out:
# Index(['Country Code', 'Year',
#        'Access to clean fuels and technologies for cooking (% of population)',
#        'Access to electricity (% of population)',
#        'Adolescent fertility rate (births per 1000 women ages 15-19)',
#        'Adolescents out of school (% of lower secondary school age)',
#        'Employment in agriculture (% of total employment) (modeled ILO estimate)',
#        'Employment in industry (% of total employment) (modeled ILO estimate)',
#        'Employment in services (% of total employment) (modeled ILO estimate)',
#        'GDP per capita (current US$)',
#        'Households and NPISHs Final consumption expenditure (annual % growth)',
#        'Individuals using the Internet (% of population)',
#        'People using at least basic drinking water services (% of population)',
#        'People using at least basic sanitation services (% of population)',
#        'People using safely managed drinking water services (% of population)',
#        'Primary completion rate total (% of relevant age group)',
#        'Unemployment total (% of total labor force) (modeled ILO estimate)',
#        'Urban population (% of total population)', 'country', 'abr',
#        'co2_prod', 'coef_ineq', 'diff_hdi_phdi', 'eys', 'eys_f', 'eys_m',
#        'gdi', 'gdi_group', 'gii', 'gii_rank', 'gni_pc_f', 'gni_pc_m', 'gnipc',
#        'hdi', 'hdi_f', 'hdi_m', 'hdi_rank', 'ihdi', 'ineq_edu', 'ineq_inc',
#        'ineq_le', 'le', 'le_f', 'le_m', 'lfpr_f', 'lfpr_m', 'loss', 'mf',
#        'mmr', 'mys', 'mys_f', 'mys_m', 'phdi', 'pop_total', 'pr_f', 'pr_m',
#        'rankdiff_hdi_phdi', 'se_f', 'se_m'],
#       dtype='object')
